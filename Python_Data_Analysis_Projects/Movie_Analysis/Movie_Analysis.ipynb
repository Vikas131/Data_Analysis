# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")
from matplotlib.pyplot import figure

# %%
movie_df = pd.read_csv("../Movie_analysis/Dataset/movies.csv")

# %%
movie_df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %% [markdown]
# ### Check for null values if any and remove them

# %%
movie_df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
movie_df.shape
# Out:
# (7668, 15)

# %%
movie_df = movie_df.dropna()

# %%
movie_df.shape
# Out:
# (5421, 15)

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5421 entries, 0 to 7652
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5421 non-null   object
#  1   rating    5421 non-null   object
#  2   genre     5421 non-null   object
#  3   year      5421 non-null   int64
#  4   released  5421 non-null   object
#  5   score     5421 non-null   float64
#  6   votes     5421 non-null   float64
#  7   director  5421 non-null   object
#  8   writer    5421 non-null   object
#  9   star      5421 non-null   object
#  10  country   5421 non-null   object
#  11  budget    5421 non-null   float64
#  12  gross     5421 non-null   float64
#  13  company   5421 non-null   object
#  14  runtime   5421 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 677.6+ KB

# %% [markdown]
# ### Change datatype of columns(Gross,Budget)

# %%
movie_df["budget"] = movie_df["budget"].astype("int64")

# %%
movie_df["gross"] = movie_df["gross"].astype("int64")

# %% [markdown]
# ### Adding a corrected year column

# %%
movie_df["year_correct"] = movie_df["released"].str.extract(pat="([0-9]{4})").astype(int)

# %%
movie_df.insert(4,"year_corrected",movie_df["year_correct"])

# %%
movie_df.drop(movie_df.columns[16],axis=1,inplace=True)

# %%
movie_df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#       year_corrected                           released  score      votes  \
# 5445            2009  December 18, 2009 (United States)    7.8  1100000.0
# 7445            2019     April 26, 2019 (United States)    8.4   903000.0
# 3045            1997  December 19, 1997 (United States)    7.8  1100000.0
# 6663            2015  December 18, 2015 (United States)    7.8   876000.0
# 7244            2018     April 27, 2018 (United States)    8.4   897000.0
#
#            director              writer               star        country  \
# 5445  James Cameron       James Cameron    Sam Worthington  United States
# 7445  Anthony Russo  Christopher Markus  Robert Downey Jr.  United States
# 3045  James Cameron       James Cameron  Leonardo DiCaprio  United States
# 6663    J.J. Abrams     Lawrence Kasdan       Daisy Ridley  United States
# 7244  Anthony Russo  Christopher Markus  Robert Downey Jr.  United States
#
#          budget       gross                company  runtime
# 5445  237000000  2847246203  Twentieth Century Fox    162.0
# 7445  356000000  2797501328         Marvel Studios    181.0
# 3045  200000000  2201647264  Twentieth Century Fox    194.0
# 6663  245000000  2069521700              Lucasfilm    138.0
# 7244  321000000  2048359754         Marvel Studios    149.0

# %%
movie_df = movie_df.sort_values("gross",ascending=False,inplace=False)

# %%
pd.set_option("display.max_rows",None)

# %% [markdown]
# ### Correlation
# #### 1. Budget High Correlation
# #### 2. Company High Correlation

# %% [markdown]
# #### 1. Scatter plot with Budget v/s Gross

# %%
plt.figure(figsize=(12,10))

plt.scatter(x=movie_df["budget"],y=movie_df["gross"],c="red")

plt.title("Budget v/s Gross Earnings")

plt.xlabel("Gross Earnings")
plt.ylabel("Budge of Film")

## Changing the xtick label to show value in 1000s instead of scientific notation
current_values = plt.gca().get_xticks()
plt.gca().set_xticklabels(['{:,.0f}'.format(x) for x in current_values])

## Changing the ytick label to show value in 1000s instead of scientific notation
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

plt.tight_layout()

plt.show()
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_32492\1292588099.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_xticklabels(['{:,.0f}'.format(x) for x in current_values])
# C:\Users\vikas\AppData\Local\Temp\ipykernel_32492\1292588099.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

# %%
movie_df.sort_values("budget",ascending=False).head()
# Out:
#                                           name rating   genre  year  \
# 7445                         Avengers: Endgame  PG-13  Action  2019
# 7244                    Avengers: Infinity War  PG-13  Action  2018
# 7075   Star Wars: Episode VIII - The Last Jedi  PG-13  Action  2017
# 7066                            Justice League  PG-13  Action  2017
# 5060  Pirates of the Caribbean: at World's End  PG-13  Action  2007
#
#       year_corrected                           released  score     votes  \
# 7445            2019     April 26, 2019 (United States)    8.4  903000.0
# 7244            2018     April 27, 2018 (United States)    8.4  897000.0
# 7075            2017  December 15, 2017 (United States)    7.0  581000.0
# 7066            2017  November 17, 2017 (United States)    6.1  418000.0
# 5060            2007       May 25, 2007 (United States)    7.1  608000.0
#
#             director              writer               star        country  \
# 7445   Anthony Russo  Christopher Markus  Robert Downey Jr.  United States
# 7244   Anthony Russo  Christopher Markus  Robert Downey Jr.  United States
# 7075    Rian Johnson        Rian Johnson       Daisy Ridley  United States
# 7066     Zack Snyder        Jerry Siegel        Ben Affleck  United States
# 5060  Gore Verbinski         Ted Elliott        Johnny Depp  United States
#
#          budget       gross               company  runtime
# 7445  356000000  2797501328        Marvel Studios    181.0
# 7244  321000000  2048359754        Marvel Studios    149.0
# 7075  317000000  1332698830  Walt Disney Pictures    152.0
# 7066  300000000   657926987          Warner Bros.    120.0
# 5060  300000000   960996492  Walt Disney Pictures    169.0

# %% [markdown]
# #### Regression plotting using seaborn for Budget v/s Gross
#
# Since from the above Scatter plot we are unable to find the exact correlation, we will be using Seaborn Regression Plot to find the correlation

# %%
sns.regplot(data=movie_df,x="budget",y="gross",scatter_kws={"color":"green"},line_kws={"color":"blue"}).set_title("Budget v/s Gross")
# Out:
# Text(0.5, 1.0, 'Budget v/s Gross')

# %% [markdown]
# Default correlation method for a dataframe is Pearson, there are 3 methods in total.
# 1. Pearson
# 2. Kendall
# 3. Spearman

# %%
movie_df.corr(numeric_only=True)
# Out:
#                     year  year_corrected     score     votes    budget  \
# year            1.000000        0.998726  0.056386  0.206021  0.327722
# year_corrected  0.998726        1.000000  0.061923  0.203098  0.320312
# score           0.056386        0.061923  1.000000  0.474256  0.072001
# votes           0.206021        0.203098  0.474256  1.000000  0.439675
# budget          0.327722        0.320312  0.072001  0.439675  1.000000
# gross           0.274321        0.268721  0.222556  0.614751  0.740247
# runtime         0.075077        0.075294  0.414068  0.352303  0.318695
#
#                    gross   runtime
# year            0.274321  0.075077
# year_corrected  0.268721  0.075294
# score           0.222556  0.414068
# votes           0.614751  0.352303
# budget          0.740247  0.318695
# gross           1.000000  0.275796
# runtime         0.275796  1.000000

# %% [markdown]
# We see a high correlation between Budget & Gross.
# i.e., As budget increases Gross increases and vice versa

# %%
correlation_matrix = movie_df.corr(numeric_only=True)

plt.figure(figsize=(12,8))

sns.heatmap(data=correlation_matrix,annot=True)

plt.title("Correlation Matrix for Numerical Features")

plt.xlabel("Movie Features")
plt.ylabel("Movie Features")

plt.show()

# %% [markdown]
# #### 2. Company Correlation

# %% [markdown]
# Since correlation can be performed only on Numeric values, we need to convert the Compnay column and others to numeric codes.
#
# To achieve this, we will be converting all the object data type columns to category data type
#
# By converting it to category, we can get a unique numeric code for each unique value

# %% [markdown]
# Categorical data is a type of data that represents categories or labels rather than numerical values.
#
# In simple words, it is a way of classifying into distinct categories, such as genders, country names, or education levels.
#
# Categorical data is handy when we have data that naturally fit into predefined options.

# %% [markdown]
# categories - returns the unique categories present in the categorical variable
#
# codes - returns the integer codes representing the categories for each element in the categorical variable

# %%
df_numerized = movie_df.copy()

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == "object"):
        df_numerized[col_name] = df_numerized[col_name].astype("category")
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized.head()
# Out:
#       name  rating  genre  year  year_corrected  released  score      votes  \
# 5445   386       5      0  2009            2009       527    7.8  1100000.0
# 7445   388       5      0  2019            2019       137    8.4   903000.0
# 3045  4909       5      6  1997            1997       534    7.8  1100000.0
# 6663  3643       5      0  2015            2015       529    7.8   876000.0
# 7244   389       5      0  2018            2018       145    8.4   897000.0
#
#       director  writer  star  country     budget       gross  company  runtime
# 5445       785    1263  1534       47  237000000  2847246203     1382    162.0
# 7445       105     513  1470       47  356000000  2797501328      983    181.0
# 3045       785    1263  1073       47  200000000  2201647264     1382    194.0
# 6663       768    1806   356       47  245000000  2069521700      945    138.0
# 7244       105     513  1470       47  321000000  2048359754      983    149.0

# %%
movie_df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#       year_corrected                           released  score      votes  \
# 5445            2009  December 18, 2009 (United States)    7.8  1100000.0
# 7445            2019     April 26, 2019 (United States)    8.4   903000.0
# 3045            1997  December 19, 1997 (United States)    7.8  1100000.0
# 6663            2015  December 18, 2015 (United States)    7.8   876000.0
# 7244            2018     April 27, 2018 (United States)    8.4   897000.0
#
#            director              writer               star        country  \
# 5445  James Cameron       James Cameron    Sam Worthington  United States
# 7445  Anthony Russo  Christopher Markus  Robert Downey Jr.  United States
# 3045  James Cameron       James Cameron  Leonardo DiCaprio  United States
# 6663    J.J. Abrams     Lawrence Kasdan       Daisy Ridley  United States
# 7244  Anthony Russo  Christopher Markus  Robert Downey Jr.  United States
#
#          budget       gross                company  runtime
# 5445  237000000  2847246203  Twentieth Century Fox    162.0
# 7445  356000000  2797501328         Marvel Studios    181.0
# 3045  200000000  2201647264  Twentieth Century Fox    194.0
# 6663  245000000  2069521700              Lucasfilm    138.0
# 7244  321000000  2048359754         Marvel Studios    149.0

# %%
correlation_matrix = df_numerized.corr(numeric_only=True)

plt.figure(figsize=(12,8))

sns.heatmap(data=correlation_matrix,annot=True)

plt.title("Correlation Matrix for Numerical Features")

plt.xlabel("Movie Features")
plt.ylabel("Movie Features")

plt.show()

# %%
correlated_mat = correlation_matrix.corr()

corr_pairs = correlated_mat.unstack()

corr_pairs
# Out:
# name            name              1.000000
#                 rating           -0.126713
#                 genre            -0.011978
#                 year             -0.078042
#                 year_corrected   -0.077133
#                 released         -0.097509
#                 score            -0.125354
#                 votes            -0.153357
#                 director         -0.057079
#                 writer           -0.059076
#                 star             -0.089699
#                 country          -0.125787
#                 budget           -0.090785
#                 gross            -0.125080
#                 company          -0.047628
#                 runtime          -0.140345
# rating          name             -0.126713
#                 rating            1.000000
#                 genre             0.344405
#                 year             -0.153577
#                 year_corrected   -0.148297
#                 released         -0.028945
#                 score            -0.001171
#                 votes            -0.271368
#                 director         -0.034457
#                 writer           -0.056366
#                 star             -0.034933
#                 country          -0.076320
#                 budget           -0.518270
#                 gross            -0.501650
#                 company          -0.324780
#                 runtime           0.029848
# genre           name             -0.011978
#                 rating            0.344405
#                 genre             1.000000
#                 year             -0.309797
#                 year_corrected   -0.303509
#                 released          0.019995
#                 score            -0.109971
#                 votes            -0.512125
#                 director         -0.007107
#                 writer            0.042525
#                 star              0.008926
#                 country          -0.056512
#                 budget           -0.751221
#                 gross            -0.661788
#                 company          -0.261427
#                 runtime          -0.310464
# year            name             -0.078042
#                 rating           -0.153577
#                 genre            -0.309797
#                 year              1.000000
#                 year_corrected    0.999939
#                 released         -0.146571
#                 score            -0.022985
#                 votes             0.271051
#                 director         -0.258607
#                 writer           -0.241164
#                 star             -0.214383
#                 country          -0.255773
#                 budget            0.469152
#                 gross             0.399142
#                 company          -0.118392
#                 runtime           0.044562
# year_corrected  name             -0.077133
#                 rating           -0.148297
#                 genre            -0.303509
#                 year              0.999939
#                 year_corrected    1.000000
#                 released         -0.148747
#                 score            -0.018961
#                 votes             0.268204
#                 director         -0.256653
#                 writer           -0.239378
#                 star             -0.213795
#                 country          -0.261187
#                 budget            0.462382
#                 gross             0.393220
#                 company          -0.123087
#                 runtime           0.045108
# released        name             -0.097509
#                 rating           -0.028945
#                 genre             0.019995
#                 year             -0.146571
#                 year_corrected   -0.148747
#                 released          1.000000
#                 score            -0.061495
#                 votes            -0.132246
#                 director         -0.084479
#                 writer           -0.072789
#                 star             -0.042134
#                 country          -0.108445
#                 budget           -0.121281
#                 gross            -0.138790
#                 company          -0.103045
#                 runtime          -0.131111
# score           name             -0.125354
#                 rating           -0.001171
#                 genre            -0.109971
#                 year             -0.022985
#                 year_corrected   -0.018961
#                 released         -0.061495
#                 score             1.000000
#                 votes             0.637193
#                 director         -0.177092
#                 writer           -0.174872
#                 star             -0.143717
#                 country          -0.214654
#                 budget            0.162249
#                 gross             0.318201
#                 company          -0.063278
#                 runtime           0.639727
# votes           name             -0.153357
#                 rating           -0.271368
#                 genre            -0.512125
#                 year              0.271051
#                 year_corrected    0.268204
#                 released         -0.132246
#                 score             0.637193
#                 votes             1.000000
#                 director         -0.265475
#                 writer           -0.272875
#                 star             -0.227915
#                 country          -0.098610
#                 budget            0.709994
#                 gross             0.837876
#                 company           0.128149
#                 runtime           0.586194
# director        name             -0.057079
#                 rating           -0.034457
#                 genre            -0.007107
#                 year             -0.258607
#                 year_corrected   -0.256653
#                 released         -0.084479
#                 score            -0.177092
#                 votes            -0.265475
#                 director          1.000000
#                 writer            0.443611
#                 star              0.005156
#                 country          -0.046025
#                 budget           -0.222489
#                 gross            -0.260025
#                 company          -0.130036
#                 runtime          -0.180860
# writer          name             -0.059076
#                 rating           -0.056366
#                 genre             0.042525
#                 year             -0.241164
#                 year_corrected   -0.239378
#                 released         -0.072789
#                 score            -0.174872
#                 votes            -0.272875
#                 director          0.443611
#                 writer            1.000000
#                 star             -0.026420
#                 country          -0.026842
#                 budget           -0.265151
#                 gross            -0.281334
#                 company          -0.126713
#                 runtime          -0.244275
# star            name             -0.089699
#                 rating           -0.034933
#                 genre             0.008926
#                 year             -0.214383
#                 year_corrected   -0.213795
#                 released         -0.042134
#                 score            -0.143717
#                 votes            -0.227915
#                 director          0.005156
#                 writer           -0.026420
#                 star              1.000000
#                 country          -0.080058
#                 budget           -0.191140
#                 gross            -0.186636
#                 company          -0.066150
#                 runtime          -0.153971
# country         name             -0.125787
#                 rating           -0.076320
#                 genre            -0.056512
#                 year             -0.255773
#                 year_corrected   -0.261187
#                 released         -0.108445
#                 score            -0.214654
#                 votes            -0.098610
#                 director         -0.046025
#                 writer           -0.026842
#                 star             -0.080058
#                 country           1.000000
#                 budget           -0.041373
#                 gross            -0.042358
#                 company           0.037896
#                 runtime          -0.200418
# budget          name             -0.090785
#                 rating           -0.518270
#                 genre            -0.751221
#                 year              0.469152
#                 year_corrected    0.462382
#                 released         -0.121281
#                 score             0.162249
#                 votes             0.709994
#                 director         -0.222489
#                 writer           -0.265151
#                 star             -0.191140
#                 country          -0.041373
#                 budget            1.000000
#                 gross             0.940175
#                 company           0.237829
#                 runtime           0.439500
# gross           name             -0.125080
#                 rating           -0.501650
#                 genre            -0.661788
#                 year              0.399142
#                 year_corrected    0.393220
#                 released         -0.138790
#                 score             0.318201
#                 votes             0.837876
#                 director         -0.260025
#                 writer           -0.281334
#                 star             -0.186636
#                 country          -0.042358
#                 budget            0.940175
#                 gross             1.000000
#                 company           0.212939
#                 runtime           0.453649
# company         name             -0.047628
#                 rating           -0.324780
#                 genre            -0.261427
#                 year             -0.118392
#                 year_corrected   -0.123087
#                 released         -0.103045
#                 score            -0.063278
#                 votes             0.128149
#                 director         -0.130036
#                 writer           -0.126713
#                 star             -0.066150
#                 country           0.037896
#                 budget            0.237829
#                 gross             0.212939
#                 company           1.000000
#                 runtime          -0.016122
# runtime         name             -0.140345
#                 rating            0.029848
#                 genre            -0.310464
#                 year              0.044562
#                 year_corrected    0.045108
#                 released         -0.131111
#                 score             0.639727
#                 votes             0.586194
#                 director         -0.180860
#                 writer           -0.244275
#                 star             -0.153971
#                 country          -0.200418
#                 budget            0.439500
#                 gross             0.453649
#                 company          -0.016122
#                 runtime           1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre           budget           -0.751221
# budget          genre            -0.751221
# genre           gross            -0.661788
# gross           genre            -0.661788
# budget          rating           -0.518270
# rating          budget           -0.518270
# votes           genre            -0.512125
# genre           votes            -0.512125
# gross           rating           -0.501650
# rating          gross            -0.501650
# company         rating           -0.324780
# rating          company          -0.324780
# genre           runtime          -0.310464
# runtime         genre            -0.310464
# year            genre            -0.309797
# genre           year             -0.309797
#                 year_corrected   -0.303509
# year_corrected  genre            -0.303509
# gross           writer           -0.281334
# writer          gross            -0.281334
# votes           writer           -0.272875
# writer          votes            -0.272875
# rating          votes            -0.271368
# votes           rating           -0.271368
#                 director         -0.265475
# director        votes            -0.265475
# budget          writer           -0.265151
# writer          budget           -0.265151
# company         genre            -0.261427
# genre           company          -0.261427
# year_corrected  country          -0.261187
# country         year_corrected   -0.261187
# director        gross            -0.260025
# gross           director         -0.260025
# year            director         -0.258607
# director        year             -0.258607
#                 year_corrected   -0.256653
# year_corrected  director         -0.256653
# country         year             -0.255773
# year            country          -0.255773
# runtime         writer           -0.244275
# writer          runtime          -0.244275
#                 year             -0.241164
# year            writer           -0.241164
# year_corrected  writer           -0.239378
# writer          year_corrected   -0.239378
# star            votes            -0.227915
# votes           star             -0.227915
# budget          director         -0.222489
# director        budget           -0.222489
# country         score            -0.214654
# score           country          -0.214654
# star            year             -0.214383
# year            star             -0.214383
# star            year_corrected   -0.213795
# year_corrected  star             -0.213795
# country         runtime          -0.200418
# runtime         country          -0.200418
# star            budget           -0.191140
# budget          star             -0.191140
# gross           star             -0.186636
# star            gross            -0.186636
# runtime         director         -0.180860
# director        runtime          -0.180860
#                 score            -0.177092
# score           director         -0.177092
# writer          score            -0.174872
# score           writer           -0.174872
# star            runtime          -0.153971
# runtime         star             -0.153971
# rating          year             -0.153577
# year            rating           -0.153577
# votes           name             -0.153357
# name            votes            -0.153357
# year_corrected  released         -0.148747
# released        year_corrected   -0.148747
# rating          year_corrected   -0.148297
# year_corrected  rating           -0.148297
# year            released         -0.146571
# released        year             -0.146571
# star            score            -0.143717
# score           star             -0.143717
# runtime         name             -0.140345
# name            runtime          -0.140345
# gross           released         -0.138790
# released        gross            -0.138790
# votes           released         -0.132246
# released        votes            -0.132246
#                 runtime          -0.131111
# runtime         released         -0.131111
# director        company          -0.130036
# company         director         -0.130036
# name            rating           -0.126713
# rating          name             -0.126713
# company         writer           -0.126713
# writer          company          -0.126713
# name            country          -0.125787
# country         name             -0.125787
# score           name             -0.125354
# name            score            -0.125354
# gross           name             -0.125080
# name            gross            -0.125080
# year_corrected  company          -0.123087
# company         year_corrected   -0.123087
# budget          released         -0.121281
# released        budget           -0.121281
# year            company          -0.118392
# company         year             -0.118392
# score           genre            -0.109971
# genre           score            -0.109971
# country         released         -0.108445
# released        country          -0.108445
#                 company          -0.103045
# company         released         -0.103045
# votes           country          -0.098610
# country         votes            -0.098610
# released        name             -0.097509
# name            released         -0.097509
# budget          name             -0.090785
# name            budget           -0.090785
#                 star             -0.089699
# star            name             -0.089699
# director        released         -0.084479
# released        director         -0.084479
# star            country          -0.080058
# country         star             -0.080058
# year            name             -0.078042
# name            year             -0.078042
#                 year_corrected   -0.077133
# year_corrected  name             -0.077133
# rating          country          -0.076320
# country         rating           -0.076320
# writer          released         -0.072789
# released        writer           -0.072789
# star            company          -0.066150
# company         star             -0.066150
#                 score            -0.063278
# score           company          -0.063278
# released        score            -0.061495
# score           released         -0.061495
# name            writer           -0.059076
# writer          name             -0.059076
# director        name             -0.057079
# name            director         -0.057079
# genre           country          -0.056512
# country         genre            -0.056512
# writer          rating           -0.056366
# rating          writer           -0.056366
# name            company          -0.047628
# company         name             -0.047628
# country         director         -0.046025
# director        country          -0.046025
# gross           country          -0.042358
# country         gross            -0.042358
# star            released         -0.042134
# released        star             -0.042134
# country         budget           -0.041373
# budget          country          -0.041373
# star            rating           -0.034933
# rating          star             -0.034933
#                 director         -0.034457
# director        rating           -0.034457
# released        rating           -0.028945
# rating          released         -0.028945
# country         writer           -0.026842
# writer          country          -0.026842
#                 star             -0.026420
# star            writer           -0.026420
# score           year             -0.022985
# year            score            -0.022985
# year_corrected  score            -0.018961
# score           year_corrected   -0.018961
# company         runtime          -0.016122
# runtime         company          -0.016122
# name            genre            -0.011978
# genre           name             -0.011978
# director        genre            -0.007107
# genre           director         -0.007107
# rating          score            -0.001171
# score           rating           -0.001171
# director        star              0.005156
# star            director          0.005156
#                 genre             0.008926
# genre           star              0.008926
#                 released          0.019995
# released        genre             0.019995
# runtime         rating            0.029848
# rating          runtime           0.029848
# country         company           0.037896
# company         country           0.037896
# writer          genre             0.042525
# genre           writer            0.042525
# runtime         year              0.044562
# year            runtime           0.044562
# year_corrected  runtime           0.045108
# runtime         year_corrected    0.045108
# votes           company           0.128149
# company         votes             0.128149
# score           budget            0.162249
# budget          score             0.162249
# gross           company           0.212939
# company         gross             0.212939
#                 budget            0.237829
# budget          company           0.237829
# year_corrected  votes             0.268204
# votes           year_corrected    0.268204
#                 year              0.271051
# year            votes             0.271051
# gross           score             0.318201
# score           gross             0.318201
# rating          genre             0.344405
# genre           rating            0.344405
# year_corrected  gross             0.393220
# gross           year_corrected    0.393220
#                 year              0.399142
# year            gross             0.399142
# budget          runtime           0.439500
# runtime         budget            0.439500
# writer          director          0.443611
# director        writer            0.443611
# runtime         gross             0.453649
# gross           runtime           0.453649
# budget          year_corrected    0.462382
# year_corrected  budget            0.462382
# year            budget            0.469152
# budget          year              0.469152
# votes           runtime           0.586194
# runtime         votes             0.586194
# votes           score             0.637193
# score           votes             0.637193
# runtime         score             0.639727
# score           runtime           0.639727
# budget          votes             0.709994
# votes           budget            0.709994
# gross           votes             0.837876
# votes           gross             0.837876
# budget          gross             0.940175
# gross           budget            0.940175
# year_corrected  year              0.999939
# year            year_corrected    0.999939
# name            name              1.000000
# gross           gross             1.000000
# budget          budget            1.000000
# country         country           1.000000
# star            star              1.000000
# writer          writer            1.000000
# director        director          1.000000
# votes           votes             1.000000
# score           score             1.000000
# released        released          1.000000
# year_corrected  year_corrected    1.000000
# year            year              1.000000
# genre           genre             1.000000
# rating          rating            1.000000
# company         company           1.000000
# runtime         runtime           1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[sorted_pairs > 0.5]

high_corr
# Out:
# votes           runtime           0.586194
# runtime         votes             0.586194
# votes           score             0.637193
# score           votes             0.637193
# runtime         score             0.639727
# score           runtime           0.639727
# budget          votes             0.709994
# votes           budget            0.709994
# gross           votes             0.837876
# votes           gross             0.837876
# budget          gross             0.940175
# gross           budget            0.940175
# year_corrected  year              0.999939
# year            year_corrected    0.999939
# name            name              1.000000
# gross           gross             1.000000
# budget          budget            1.000000
# country         country           1.000000
# star            star              1.000000
# writer          writer            1.000000
# director        director          1.000000
# votes           votes             1.000000
# score           score             1.000000
# released        released          1.000000
# year_corrected  year_corrected    1.000000
# year            year              1.000000
# genre           genre             1.000000
# rating          rating            1.000000
# company         company           1.000000
# runtime         runtime           1.000000
# dtype: float64

# %% [markdown]
# #### Final review - Votes and budget have the highest correlation to gross earnings
# #### Company has low correlation
